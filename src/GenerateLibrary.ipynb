# %%
! jupyter nbconvert --to 'python' affine.ipynb
! jupyter nbconvert --to 'python' applylut.ipynb
! jupyter nbconvert --to 'python' bwlp.ipynb
! jupyter nbconvert --to 'python' circle.ipynb
! jupyter nbconvert --to 'python' colormap.ipynb
! jupyter nbconvert --to 'python' comb.ipynb
! jupyter nbconvert --to 'python' conv.ipynb
! jupyter nbconvert --to 'python' cos.ipynb
! jupyter nbconvert --to 'python' dct.ipynb
! jupyter nbconvert --to 'python' dctmatrix.ipynb
! jupyter nbconvert --to 'python' dft.ipynb
! jupyter nbconvert --to 'python' dftmatrix.ipynb
! jupyter nbconvert --to 'python' dftshift.ipynb
! jupyter nbconvert --to 'python' dftview.ipynb
! jupyter nbconvert --to 'python' ellipse.ipynb
! jupyter nbconvert --to 'python' gaussian.ipynb
! jupyter nbconvert --to 'python' gshow.ipynb
! jupyter nbconvert --to 'python' h2percentile.ipynb
! jupyter nbconvert --to 'python' h2stats.ipynb
! jupyter nbconvert --to 'python' haarmatrix.ipynb
! jupyter nbconvert --to 'python' hadamard.ipynb
! jupyter nbconvert --to 'python' hadamardmatrix.ipynb
! jupyter nbconvert --to 'python' histogram.ipynb
! jupyter nbconvert --to 'python' idct.ipynb
! jupyter nbconvert --to 'python' idft.ipynb
! jupyter nbconvert --to 'python' idftshift.ipynb
! jupyter nbconvert --to 'python' ihadamard.ipynb
! jupyter nbconvert --to 'python' interpollin.ipynb
! jupyter nbconvert --to 'python' isccsym.ipynb
! jupyter nbconvert --to 'python' isolines.ipynb
! jupyter nbconvert --to 'python' log.ipynb
! jupyter nbconvert --to 'python' logfilter.ipynb
! jupyter nbconvert --to 'python' mosaic.ipynb
! jupyter nbconvert --to 'python' normalize.ipynb
! jupyter nbconvert --to 'python' pca.ipynb
! jupyter nbconvert --to 'python' pconv.ipynb
! jupyter nbconvert --to 'python' phasecorr.ipynb
! jupyter nbconvert --to 'python' polar.ipynb
! jupyter nbconvert --to 'python' ptrans.ipynb
! jupyter nbconvert --to 'python' ramp.ipynb
! jupyter nbconvert --to 'python' rectangle.ipynb
! jupyter nbconvert --to 'python' rgb2hsv.ipynb
! jupyter nbconvert --to 'python' sat.ipynb
! jupyter nbconvert --to 'python' sobel.ipynb
# Out:
# [NbConvertApp] Converting notebook affine.ipynb to python
# [NbConvertApp] Writing 5468 bytes to affine.py
# [NbConvertApp] Converting notebook applylut.ipynb to python
# [NbConvertApp] Writing 3944 bytes to applylut.py
# [NbConvertApp] Converting notebook bwlp.ipynb to python
# [NbConvertApp] Writing 3510 bytes to bwlp.py
# [NbConvertApp] Converting notebook circle.ipynb to python
# [NbConvertApp] Writing 1581 bytes to circle.py
# [NbConvertApp] Converting notebook colormap.ipynb to python
# [NbConvertApp] Writing 5519 bytes to colormap.py
# [NbConvertApp] Converting notebook comb.ipynb to python
# [NbConvertApp] Writing 3113 bytes to comb.py
# [NbConvertApp] Converting notebook conv.ipynb to python
# [NbConvertApp] Writing 3617 bytes to conv.py
# [NbConvertApp] Converting notebook cos.ipynb to python
# [NbConvertApp] Writing 3911 bytes to cos.py
# [NbConvertApp] Converting notebook dct.ipynb to python
# [NbConvertApp] Writing 3015 bytes to dct.py
# [NbConvertApp] Converting notebook dctmatrix.ipynb to python
# [NbConvertApp] Writing 1630 bytes to dctmatrix.py
# [NbConvertApp] Converting notebook dft.ipynb to python
# [NbConvertApp] Writing 3514 bytes to dft.py
# [NbConvertApp] Converting notebook dftmatrix.ipynb to python
# [NbConvertApp] Writing 2434 bytes to dftmatrix.py
# [NbConvertApp] Converting notebook dftshift.ipynb to python
# [NbConvertApp] Writing 2202 bytes to dftshift.py
# [NbConvertApp] Converting notebook dftview.ipynb to python
# [NbConvertApp] Writing 1759 bytes to dftview.py
# [NbConvertApp] Converting notebook ellipse.ipynb to python
# [NbConvertApp] Writing 2375 bytes to ellipse.py
# [NbConvertApp] Converting notebook gaussian.ipynb to python
# [NbConvertApp] Writing 3346 bytes to gaussian.py
# [NbConvertApp] Converting notebook gshow.ipynb to python
# [NbConvertApp] Writing 3691 bytes to gshow.py
# [NbConvertApp] Converting notebook h2percentile.ipynb to python
# [NbConvertApp] Writing 2999 bytes to h2percentile.py
# [NbConvertApp] Converting notebook h2stats.ipynb to python
# [NbConvertApp] Writing 4793 bytes to h2stats.py
# [NbConvertApp] Converting notebook haarmatrix.ipynb to python
# [NbConvertApp] Writing 2083 bytes to haarmatrix.py
# [NbConvertApp] Converting notebook hadamard.ipynb to python
# [NbConvertApp] Writing 1357 bytes to hadamard.py
# [NbConvertApp] Converting notebook hadamardmatrix.ipynb to python
# [NbConvertApp] Writing 1439 bytes to hadamardmatrix.py
# [NbConvertApp] Converting notebook histogram.ipynb to python
# [NbConvertApp] Writing 2826 bytes to histogram.py
# [NbConvertApp] Converting notebook idct.ipynb to python
# [NbConvertApp] Writing 3247 bytes to idct.py
# [NbConvertApp] Converting notebook idft.ipynb to python
# [NbConvertApp] Writing 2242 bytes to idft.py
# [NbConvertApp] Converting notebook idftshift.ipynb to python
# [NbConvertApp] Writing 3406 bytes to idftshift.py
# [NbConvertApp] Converting notebook ihadamard.ipynb to python
# [NbConvertApp] Writing 1628 bytes to ihadamard.py
# [NbConvertApp] Converting notebook interpollin.ipynb to python
# [NbConvertApp] Writing 5462 bytes to interpollin.py
# [NbConvertApp] Converting notebook isccsym.ipynb to python
# [NbConvertApp] Writing 3827 bytes to isccsym.py
# [NbConvertApp] Converting notebook isolines.ipynb to python
# [NbConvertApp] Writing 1470 bytes to isolines.py
# [NbConvertApp] Converting notebook log.ipynb to python
# [NbConvertApp] Writing 4058 bytes to log.py
# [NbConvertApp] Converting notebook logfilter.ipynb to python
# [NbConvertApp] Writing 2058 bytes to logfilter.py
# [NbConvertApp] Converting notebook mosaic.ipynb to python
# [NbConvertApp] Writing 2709 bytes to mosaic.py
# [NbConvertApp] Converting notebook normalize.ipynb to python
# [NbConvertApp] Writing 3270 bytes to normalize.py
# [NbConvertApp] Converting notebook pca.ipynb to python
# [NbConvertApp] Writing 5865 bytes to pca.py
# [NbConvertApp] Converting notebook pconv.ipynb to python
# [NbConvertApp] Writing 4750 bytes to pconv.py
# [NbConvertApp] Converting notebook phasecorr.ipynb to python
# [NbConvertApp] Writing 3898 bytes to phasecorr.py
# [NbConvertApp] Converting notebook polar.ipynb to python
# [NbConvertApp] Writing 2993 bytes to polar.py
# [NbConvertApp] Converting notebook ptrans.ipynb to python
# [NbConvertApp] Writing 4145 bytes to ptrans.py
# [NbConvertApp] Converting notebook ramp.ipynb to python
# [NbConvertApp] Writing 3456 bytes to ramp.py
# [NbConvertApp] Converting notebook rectangle.ipynb to python
# [NbConvertApp] Writing 1814 bytes to rectangle.py
# [NbConvertApp] Converting notebook rgb2hsv.ipynb to python
# [NbConvertApp] Writing 3499 bytes to rgb2hsv.py
# [NbConvertApp] Converting notebook sat.ipynb to python
# [NbConvertApp] Writing 3822 bytes to sat.py
# [NbConvertApp] Converting notebook sobel.ipynb to python
# [NbConvertApp] Writing 2638 bytes to sobel.py
